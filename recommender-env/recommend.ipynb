# %%
pip install scikit-surprise
# Out:
# ...
#
#   Using cached scikit_surprise-1.1.4.tar.gz (154 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Using cached scipy-1.15.2-cp310-cp310-win_amd64.whl (41.2 MB)
# ...
#   Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# ...
# Failed to build scikit-surprise
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\Users\Acer\AppData\Local\Programs\Python\Python310\python.exe' 'c:\Users\Acer\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' build_wheel 'C:\Users\Acer\AppData\Local\Temp\tmpj0pr6f9_'
#        cwd: C:\Users\Acer\AppData\Local\Temp\pip-install-yntg4ac6\scikit-surprise_699ef024475141c5b66b5a09561df351
#   Complete output (155 lines):
# ...

# %%
import pandas as pd
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
import pickle

# Load rating data
ratings_df = pd.read_csv("ratings.csv")
prefs_df = pd.read_csv("prefs.csv")
courses_df = pd.read_csv("courses.csv")

reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(ratings_df[['user_id', 'course_id', 'rating']], reader)
trainset = data.build_full_trainset()

model = SVD()
model.fit(trainset)

# Get user preferences
# def recommend_courses_for_user(user_id, top_n=10):
#     user_categories = prefs_df[prefs_df['user_id'] == user_id]['category_id'].tolist()

#     if not user_categories:
#         print(f"⚠️ No category preferences found for user {user_id}")
#         return pd.DataFrame()

#     rated_courses = ratings_df[ratings_df['user_id'] == user_id]['course_id'].tolist()

#     candidate_courses = courses_df[
#         (courses_df['category_id'].isin(user_categories)) &
#         (~courses_df['course_id'].isin(rated_courses))
#     ]

#     if candidate_courses.empty:
#         print(f"ℹ️ No new courses to recommend for user {user_id} in their preferred categories.")
#         return pd.DataFrame()

#     candidate_courses['predicted_rating'] = candidate_courses['course_id'].apply(
#         lambda cid: model.predict(user_id, cid).est
#     )

#     top_courses = candidate_courses.sort_values(by='predicted_rating', ascending=False).head(top_n)
#     return top_courses[['course_id', 'predicted_rating']]

with open("trained_model.pkl", "wb") as f:
    pickle.dump(model, f)

print("✅ Model trained and saved as 'trained_model.pkl'")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 from surprise import Dataset, Reader, SVD
#       3 from surprise.model_selection import train_test_split
#       4 import pickle
#
# ModuleNotFoundError: No module named 'surprise'
